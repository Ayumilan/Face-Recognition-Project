# %%
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_extractor(img):
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces == ():
        return None
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face
    
cap = cv2.VideoCapture(0)
count = 0


while True:

    ret, photo = cap.read()
    if face_extractor(photo) is not None:
        count += 1
        face = cv2.resize(face_extractor(photo), (100, 100))

        file_name_path = 'C:\\Users\\ayush\\Documents\\ml\\sampleiamge\\' + str(count) + '.JPG'
        cv2.imwrite(file_name_path, face)

        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        pass

    if cv2.waitKey(1) == 27 or count == 100: 
        break
        
cap.release()
cv2.destroyAllWindows()     
print("Collecting Samples Complete")
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_22480\2521176255.py:10: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if faces == ():
# Collecting Samples Complete

# %%
cap.release()

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join
print(cv2.__version__)
# Get the training data we previously made
data_path = 'C:\\Users\\ayush\\Documents\\ml\\sampleiamge\\'

onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]


Training_Data, Labels = [], []

for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)

Labels = np.asarray(Labels, dtype=np.int32)
model = cv2.face.LBPHFaceRecognizer_create() 

model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained successfully")
# Out:
# 4.7.0
# Model trained successfully

# %%
import cv2
import numpy as np
import os
import urllib.request

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):

    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []LBPHFaceRecognizer 

    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()

    image, face = face_detector(frame)

    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = model.predict(face)
        print(results)
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is User'

        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)

        if confidence > 80:
           
            cv2.putText(image, "Welcome Milan!!", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            
            #os.system("curl /kxzehhlpr5.execute-api.ap-south-1.amazonaws.com/test/unlock")
            
            #AI MODEL
            request_url = urllib.request.urlopen("https://cgri00lo1l.execute-api.ap-south-1.amazonaws.com/test/unlock")
            print( request_url.read())
            
            cv2.imshow('Face Recognition', image )
          

        else:
            request_url = urllib.request.urlopen("https://cgri00lo1l.execute-api.ap-south-1.amazonaws.com/test/lock")
            print( request_url.read())
            cv2.putText(image, "i dont know", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)

            
            cv2.imshow('Face Recognition', image )

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass

    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ayush\AppData\Local\Temp\ipykernel_22480\1706590290.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# (27, 112.97147020048165)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (27, 107.03401516764795)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (27, 102.21994230648284)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (27, 105.63009244593084)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (27, 106.69522107048537)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (27, 103.70109397288937)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (27, 101.86755812325104)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (27, 107.24908955705888)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (27, 102.89159675175193)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (27, 102.84639601813869)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (11, 104.74893285879143)
# b'{"statusCode": 200, "body": "\\"User Locked!\\""}'
# (0, 73.04572560426352)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (78, 70.10870941883849)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (0, 72.89959050632277)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (0, 71.57283208693543)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (0, 72.16244340316167)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (20, 69.08421663722727)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (17, 71.08138312751578)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (17, 69.39778450842857)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (27, 69.67611807572128)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (20, 70.77217300136515)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (78, 69.66022353291416)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (20, 68.23521356687414)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (20, 70.3396756179634)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (20, 71.08947960674047)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (14, 70.38457391259368)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (17, 72.58885686451754)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (18, 72.281828217919)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (27, 71.8093961931979)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (0, 72.02865579373861)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (11, 70.69254258886485)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (78, 71.31050681603425)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (78, 72.70136847187591)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (78, 73.71140520103918)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'
# (78, 71.29931539915648)
# b'{"statusCode": 200, "body": "\\"User Unlocked!\\""}'

# %%
cap.release()
